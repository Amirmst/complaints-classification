# %%
import pandas as pd

pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 100)
pd.options.display.float_format = "{:,.2f}".format

# %%
data = pd.read_csv("complaints_10-dev-subset.txt", sep="\t", skiprows=1,
                      dtype={1: str},
                      names=["fiscal_year", "charge_num", "state", "num_employees_code",
                             "num_employees", "naics_code", "naics_desc", "type_code",
                             "type", "birth_date", "sex", "date_received", "date_closed",
                             "closure_code", "closure_action", "monetary_benefits", "statute_code",
                             "statute", "basis_code", "basis", "issue_code", "issue",
                             "court_filing_date", "civil_action_num", "court", "resolution_date",
                             "case_type", "litigation_monetary_benefits"])
data.head()
# Out:
#       fiscal_year charge_num state           num_employees_code  \
# 0    3,288,411.72         MD     B          101 - 200 Employees
# 1  3,593,445.5595         AL     U  Unknown Number Of Employees
# 2  3,593,445.5595         AL     U  Unknown Number Of Employees
# 3  3,593,445.5595         AL     U  Unknown Number Of Employees
# 4  3,848,821.6365         PA     D               501+ Employees
#
#    num_employees                        naics_code naics_desc  \
# 0     611,110.00  Elementary and Secondary Schools          E
# 1            nan                               NaN          E
# 2            nan                               NaN          E
# 3            nan                               NaN          E
# 4     611,110.00  Elementary and Secondary Schools          M
#
#                        type_code      type birth_date       sex  \
# 0               Private Employer  11/13/66          N  03/03/10
# 1               Private Employer  05/02/79          F  02/03/10
# 2               Private Employer  05/02/79          F  02/03/10
# 3               Private Employer  05/02/79          F  02/03/10
# 4  Private Elem/Secondary School  09/24/76          F  10/27/09
#
#    date_received date_closed closure_code             closure_action  \
# 0            nan    03/03/10           M3    No Cause Finding Issued
# 1            nan    07/30/10           N2  NRTS Issued At CP Request
# 2            nan    07/30/10           N2  NRTS Issued At CP Request
# 3            nan    07/30/10           N2  NRTS Issued At CP Request
# 4            nan    11/12/09           N2  NRTS Issued At CP Request
#
#    monetary_benefits statute_code    statute basis_code        basis  \
# 0                nan            A       ADEA         OA          Age
# 1                nan            T  Title VII         OR  Retaliation
# 2                nan            T  Title VII         OR  Retaliation
# 3                nan            T  Title VII         GF   Sex-Female
# 4                nan            T  Title VII         GF   Sex-Female
#
#   issue_code               issue  court_filing_date  civil_action_num  court  \
# 0         T2    Terms/Conditions                nan               nan    nan
# 1         D2           Discharge                nan               nan    nan
# 2         B3  Benefits-Insurance                nan               nan    nan
# 3         B3  Benefits-Insurance                nan               nan    nan
# 4         S4   Sexual Harassment                nan               nan    nan
#
#    resolution_date  case_type  litigation_monetary_benefits
# 0              nan        nan                           nan
# 1              nan        nan                           nan
# 2              nan        nan                           nan
# 3              nan        nan                           nan
# 4              nan        nan                           nan
