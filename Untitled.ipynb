# %%
import pandas

df = pandas.read_csv('complaints_10.txt', sep='\t', skiprows=1,dtype={1: str})
df.head()
# Out:
# /Users/amirgamenet/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (22,23,24,25,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      3,288,411.72  MD  B          101 - 200 Employees    611110  \
# 0    3,288,411.72  MD  B          101 - 200 Employees  611110.0
# 1    3,288,411.72  MD  B          101 - 200 Employees  611110.0
# 2  3,593,445.5595  AL  U  Unknown Number Of Employees       NaN
# 3  3,593,445.5595  AL  U  Unknown Number Of Employees       NaN
# 4  3,593,445.5595  AL  U  Unknown Number Of Employees       NaN
#
#    Elementary and Secondary Schools  E  Private Employer  11/13/66  N  ...  \
# 0  Elementary and Secondary Schools  E  Private Employer  11/13/66  N  ...
# 1  Elementary and Secondary Schools  E  Private Employer  11/13/66  N  ...
# 2                               NaN  E  Private Employer  05/02/79  F  ...
# ...
